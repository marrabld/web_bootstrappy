# %%
wavelength   = [412, 440, 488, 510, 532, 555, 650, 676, 715]
a_star_p = [0.0366, 0.0434, 0.0304, 0.0211, 0.0145, 0.0098, 0.0094, 0.0244, 0.0015]
a_star_d = [0.0071, 0.0055, 0.0031, 0.0024, 0.0017, 0.0014, 0.0012, 0.0017, 0.0008]
a_star_m = [0.0672, 0.0468, 0.0303, 0.0230, 0.0178, 0.0132, 0.0082, 0.0074, 0.0069]
a_star_g = [1.6619, 1.0000, 0.4540, 0.3253, 0.2503, 0.1745, 0.0463, 0.0208, 0.0000]
bb_star_ph = [0.00194, 0.00170, 0.00183, 0.00199, 0.00178, 0.00169, 0.00157, 0.00147, 0.00144]
bb_star_m = [0.02075, 0.01880, 0.01854, 0.01898, 0.01710, 0.01639, 0.01602, 0.01444, 0.01320]
bb_star_g = [0, 0, 0, 0, 0, 0, 0, 0, 0]
aw = [0.00469, 0.00635, 0.01454, 0.0325, 0.0442, 0.0592, 0.34, 0.4546, 1.029]#  %replicate to size of X
bbw = [0.00333, 0.00245, 0.00158, 0.0013, 0.00109, 0.000925, 0.0005, 0.00037, 0.000325] # , %replicate to size of X

# %%
import pylab

pylab.plot(wavelength, bb_star_ph)
